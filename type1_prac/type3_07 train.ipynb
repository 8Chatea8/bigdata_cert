# %% [markdown]
# ## 07. 독립성 겁정
#
# 길벗 대학에는 빅데이터 분석기사 캠프와 정보처리기사 캠프가 있다. 최근 두 캠프 학생들 사이에서 주최한 세미나에 참여햐려면 등록을 해야한다. 각 캠프의 세미나 등록 여부를 조사한 결과는 아래와 같다. 캠프와 세미나 등록 여부가 서로 독립적인지 검정하시오. (유의수준 0.05)
# * 귀무가설($H_0$): 캠프와 세미나 등록 여부는 서로 독립적이다.
# * 대립가설($H_1$): 캠프와 세미나 등록 여부는 서로 독립적이 아니다.
#
# 1. 캠프와 세미나 등록 여부가 서로 독립적인지를 검정하기 위한 검정 통계량을 구하시오.
# 2. 위 통계량에 대한 p-value를 구하시오.
# 3. 위의 검정 결과를 유의수준 0.05하에서 귀무가설을 기준으로 채택/기각 중 선택해 입력하시오.

# %%
# 데이터
import pandas as pd
df = pd.DataFrame({
        '캠프': ['빅분기']*80 + ['정처기']*100,
        '등록여부': ['등록']*50 + ['등록안함']*30 + ['등록']*60 + ['등록안함']*40
})
print(df.head())
