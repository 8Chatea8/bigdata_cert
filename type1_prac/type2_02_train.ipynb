# %% [markdown]
# ## 02. 노트북 가격 예측
#
# * 노트북 정보로 가격을 예측하시오.
#     * 제공된 데이터 목록: laptop_train.csv, laptop_test.csv
#     * 에측할 컬럼: price
# * 학습용 데이터(train)를 이용해 노트북 가격을 예측하는 모델을 만든 후 이를 평가용 데이터(test)에 적용해 얻은 예측값을 다음과 같은 형식의 CSV 파일로 생성하시오.
# 제출 파일은 다음 1개의 컬럼을 포함해야 한다.
# * pred: 예측값(가격)
# * 제출 파일명: 'result.csv'
# 제출한 모델의 성능은 R^2(결정 계수) 평가지표에 따라 채점한다.
# * 제출 csv 파일명 및 형태: result.csv
# ```python
# pred
# 37000
# 39000
# 57000
# ```

# %%
import pandas as pd

train_df = pd.read_csv('../bigdata_analyst_cert/part2/ch8/laptop_train.csv')
test_df = pd.read_csv('../bigdata_analyst_cert/part2/ch8/laptop_test.csv')

# %%
print(train_df.shape)
print(test_df.shape)
print('-'*50)
print(train_df.head())
print(test_df.head())
print('-'*50)
# Out:
# (91, 10)
# (39, 9)
# --------------------------------------------------
#     Brand     Model Series Processor Processor_Gen   RAM Hard_Disk_Capacity  \
# 0    ASUS  VivoBook     15        i3          10th   8.0         512 GB SSD
# 1    DELL  Inspiron    NaN        i3          11th   8.0           1 TB HDD
# 2    ASUS  VivoBook     15        i7          10th  16.0         512 GB SSD
# 3    DELL       NaN    NaN        i3          10th   8.0           1 TB HDD
# 4  Lenovo   IdeaPad   Slim        i3          11th   8.0         512 GB SSD
#
#                 OS  Rating  Price
# 0  Windows 11 Home     4.3  37940
# 1  Windows 11 Home     3.7  39040
# 2  Windows 11 Home     4.1  57940
# 3       Windows 10     3.2  41340
# 4  Windows 10 Home     4.4  45440
#     Brand    Model Series Processor Processor_Gen  RAM Hard_Disk_Capacity  \
# 0    DELL   Vostro    NaN        i3          10th  8.0         256 GB SSD
# 1  Lenovo  IdeaPad      3        i3          10th  8.0         256 GB SSD
# ...

# %%
print(train_df.info())
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               91 non-null     object
#  1   Model               82 non-null     object
#  2   Series              55 non-null     object
#  3   Processor           86 non-null     object
#  4   Processor_Gen       86 non-null     object
#  5   RAM                 85 non-null     float64
#  6   Hard_Disk_Capacity  85 non-null     object
#  7   OS                  85 non-null     object
#  8   Rating              91 non-null     float64
#  9   Price               91 non-null     int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
# ...

# %%
train_df['Brand'].value_counts()
# Out:
# Brand
# DELL      29
# ASUS      21
# Lenovo    21
# HP        11
# APPLE      5
# acer       2
# MSI        2
# Name: count, dtype: int64

# %%
test_df['Brand'].value_counts()
# Out:
# Brand
# DELL         11
# ASUS          8
# Lenovo        7
# HP            6
# acer          2
# APPLE         2
# realme        1
# MICROSOFT     1
# MSI           1
# Name: count, dtype: int64

# %%
train_df['Model'].value_counts()
# Out:
# Model
# Inspiron      18
# VivoBook       9
# IdeaPad        8
# Vostro         8
# Ideapad        6
# Vivobook       5
# Ryzen          4
# 2020           4
# Pavilion       3
# Chromebook     2
# TUF            1
# Nitro          1
# HP             1
# ASUS           1
# 15q            1
# Thinkpad       1
# Swift          1
# ZenBook        1
# Envy           1
# 3000           1
# IDEAPAD        1
# v15            1
# MacBook        1
# GF63           1
# APU            1
# Name: count, dtype: int64

# %%
test_df['Model'].value_counts()
# Out:
# Model
# Inspiron      8
# IdeaPad       7
# Vostro        2
# VivoBook      2
# ROG           2
# MacBook       2
# 250-G6        1
# Aspire        1
# Book          1
# Travelmate    1
# Ryzen         1
# Notebook      1
# Vivobook      1
# Surface       1
# Katana        1
# TUF           1
# HP            1
# Name: count, dtype: int64

# %%
train_df[train_df['Model']=='Inspiron']
# Out:
#    Brand     Model  Series Processor Processor_Gen   RAM Hard_Disk_Capacity  \
# 1   DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 9   DELL  Inspiron     NaN        i3          11th   8.0         256 GB SSD
# 10  DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 17  DELL  Inspiron     NaN        i3          11th   8.0         512 GB SSD
# 20  DELL  Inspiron  Athlon     3050U             -   4.0         256 GB SSD
# 39  DELL  Inspiron     NaN        i5          11th  16.0         512 GB SSD
# 45  DELL  Inspiron     NaN        i5          11th  16.0         512 GB SSD
# 46  DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 60  DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 63  DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 71  DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# ...

# %%
train_df[train_df['Series'].isna()]
# Out:
#      Brand     Model Series Processor Processor_Gen   RAM Hard_Disk_Capacity  \
# 1     DELL  Inspiron    NaN        i3          11th   8.0           1 TB HDD
# 3     DELL       NaN    NaN        i3          10th   8.0           1 TB HDD
# 7       HP       NaN    NaN        i3          10th   8.0         512 GB SSD
# 9     DELL  Inspiron    NaN        i3          11th   8.0         256 GB SSD
# 10    DELL  Inspiron    NaN        i3          11th   8.0           1 TB HDD
# 17    DELL  Inspiron    NaN        i3          11th   8.0         512 GB SSD
# 23      HP       15q    NaN        i3           7th   4.0           1 TB HDD
# 26      HP       NaN    NaN        i3          11th   8.0         512 GB SSD
# 30  Lenovo       NaN    NaN        i3          11th   4.0         256 GB SSD
# 32      HP       NaN    NaN        i5          11th   8.0         512 GB SSD
# 34  Lenovo       NaN    NaN        i3          10th   8.0         512 GB SSD
# ...

# %%
train_df['Series'].value_counts()
# Out:
# Series
# 3           10
# 15           6
# Gaming       6
# Slim         4
# Ryzen        4
# Macbook      4
# 14           3
# 5            3
# K15          3
# Celeron      2
# Ultra        1
# 3405         1
# TUF          1
# Athlon       1
# Pavilion     1
# Duo          1
# 530s         1
# Air          1
# Thin         1
# Dual         1
# Name: count, dtype: int64

# %%
train_df['Processor'].value_counts()
# Out:
# Processor
# i3          42
# i5          23
# -            4
# 5600H        3
# i7           3
# 3250U        2
# 3450U        1
# 4600H        1
# 3050U        1
# 5600U        1
# AMD          1
# 4800H        1
# 5500U        1
# A9           1
# R3-3250U     1
# Name: count, dtype: int64
