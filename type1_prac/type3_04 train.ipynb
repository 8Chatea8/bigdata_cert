# %% [markdown]
# ## 04. 일원 분산 분석
#
# 4개의 중학교에서 다른 교육 방법을 사용해 학생들에게 수학을 가르쳤다. 각 중학교의 학생들이 받은 교육 후의 수학 성적은 다음과 같다. 이 4개의 교육 방법에 따른 성적 차이가 통계적으로 유의미한지 5%의 유의수준에서 검정하시오.
# * 귀무가설($H_0$): 모든 중학교의 학생들의 수학 성적 평균은 동일하다.
# * 대립가설($H_1$): 적어도 2개 중학교의 학생들의 수학 성적 평균은 다르다. (4개 교육 방법 중 최소한 하나의 방법이 다른 방법들과 성적에서 차이가 있다.)
#
# 1. 각 그룹의 수학 성적에 대해 Shaprio-Wilk 검정을 통한 정규성을 확인하고, 그 결과의 p-value를 구하시오.
# 2. 4개 그룹의 수학 성적이 등분산성을 갖는지 확인하기 위해 Levene 검정을 실시하고, p-value를 구하시오.
# 3. 유의수준 0.05 하에서 귀무가설을 기준으로 검정의 결과를 채택/기각 중 선택해 입력하시오.
# 4. 그룹 변수의 자유도를 구하시오.
# 5. 잔차의 자유도를 구하시오.
# 6. 성적의 제곱합을 구하시오.
# 7. 성적의 평균 제곱을 구하시오.
# 8. F-통계량의 값을 구하시오.
# 9. 성적에 대한 p-value를 구하시오.

# %%
# 데이터
import pandas as pd
df = pd.read_csv("../bigdata_analyst_cert/part3/ch6/math.csv")
print(df.head())
# Out:
#     groups  scores
# 0  group_A      85
# 1  group_A      88
# 2  group_A      90
# 3  group_A      82
# 4  group_A      87

# %%
# 각 그룹의 수학 성적에 대한 Shapiro-Wilk 검정
from scipy import stats

A_score = df[df['groups'] == 'group_A']['scores']
B_score = df[df['groups'] == 'group_B']['scores']
C_score = df[df['groups'] == 'group_C']['scores']
D_score = df[df['groups'] == 'group_D']['scores']


A_shaprio = stats.shapiro(A_score)
B_shaprio = stats.shapiro(B_score)
C_shaprio = stats.shapiro(C_score)
D_shaprio = stats.shapiro(D_score)

print(A_shaprio)
print(B_shaprio)
print(C_shaprio)
print(D_shaprio)
# Out:
# ShapiroResult(statistic=np.float64(0.9715896670696531), pvalue=np.float64(0.9051800443853569))
# ShapiroResult(statistic=np.float64(0.9499422438060351), pvalue=np.float64(0.6678172590861611))
# ShapiroResult(statistic=np.float64(0.9299424104842702), pvalue=np.float64(0.44732595113862045))
# ShapiroResult(statistic=np.float64(0.9065684572704982), pvalue=np.float64(0.25824165549017347))

# %%
# 2. 4개 그룹의 수학 성적이 등분산성을 갖는지 확인하기 위해 Levene 검정을 실시하고, p-value를 구하시오.

from scipy import stats

stats.levene(A_score, B_score, C_score, D_score)
# Out:
# LeveneResult(statistic=np.float64(1.757685352622062), pvalue=np.float64(0.17270284963232105))

# %%
# 4. 그룹 변수의 자유도를 구하시오.
# 5. 잔차의 자유도를 구하시오.
# 6. 성적의 제곱합을 구하시오.
# 7. 성적의 평균 제곱을 구하시오.
# 8. F-통계량의 값을 구하시오.
# 9. 성적에 대한 p-value를 구하시오.

from statsmodels.formula.api import ols
model = ols('scores~groups', df).fit()

# %%
model

# %%
from statsmodels.stats.anova import anova_lm
anova_lm(model)
# Out:
#             df  sum_sq     mean_sq          F        PR(>F)
# groups     3.0   411.8  137.266667  34.174274  1.240642e-10
# Residual  36.0   144.6    4.016667        NaN           NaN

# %%
from scipy import stats

help(stats.f_oneway)

# %%
stats.f_oneway(A_score, B_score, C_score, D_score)
# Out:
# F_onewayResult(statistic=np.float64(34.174273858921204), pvalue=np.float64(1.240641542851024e-10))
